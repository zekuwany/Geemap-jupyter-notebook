# %% [markdown]
# <a href="https://colab.research.google.com/github/zekuwany/Geemap-jupyter-notebook/blob/main/10_shapefiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/10_shapefiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %%
import geemap

# %%
geemap.show_youtube('OlNlqfj4uHo')

# %%
Map = geemap.Map()
Map

# %%
countries_shp = '../data/Oromia_Region.shp'
countries = geemap.shp_to_ee(countries_shp)
Map.addLayer(countries, {}, 'Countries')

# %%
states_shp = '../data/East_HZ.shp'
states = geemap.shp_to_ee(states_shp)
Map.addLayer(states, {}, 'US States')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# No module named 'pycrs'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_559/2717214598.py in <cell line: 0>()
#       1 states_shp = '../data/East_HZ.shp'
#       2 states = geemap.shp_to_ee(states_shp)
# ----> 3 Map.addLayer(states, {}, 'US States')
#
# NameError: name 'Map' is not defined

# %%
cities_shp = '../data/Gara_Mullata_Park.shp'
cities = geemap.shp_to_ee(cities_shp)
Map.addLayer(cities, {}, 'US Cities')

# %%
geemap.ee_to_shp(countries, filename='../data/countries_new.shp')

# %%
geemap.ee_export_vector(states, filename='../data/states.csv')

# %%
geemap.ee_export_vector(states, filename='../data/states.kml')

# %%
geemap.ee_export_vector(states, filename='../data/states.kmz')
